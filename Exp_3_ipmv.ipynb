# %% [markdown]
# <a href="https://colab.research.google.com/github/Neeraton/IPMV/blob/main/Exp_3_ipmv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from io import BytesIO
import numpy as np
import matplotlib.pylab as plt
import cv2
from PIL import Image
from google.colab.patches import cv2_imshow
from google.colab import files
#uploaded = files.upload()
#img=Image.open(BytesIO(uploaded['cameraman.png']))
#plt.imshow(img)
img = cv2.imread('walkbridge.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img,cmap=plt.cm.gray)

# %%
img
# Out:
# array([[ 93,  81,  85, ..., 162, 134,  85],
#        [105,  97,  94, ..., 127, 106, 104],
#        [ 89,  85, 112, ..., 100,  91,  97],
#        ...,
#        [ 76,  85,  88, ...,  76,  97, 105],
#        [ 89,  97,  98, ...,  77,  69,  81],
#        [118, 113,  97, ..., 102,  69,  69]], dtype=uint8)

# %%
[m,n] = img.shape;

m,n
# Out:
# (512, 512)

# %%
mask = np.ones([3, 3], dtype = int)
#mask=np.array([[-1,0,1],[-2,0,2],[-1,0,1]])
mask = mask / 9

#Rmask=np.array([[1,0],[0,-1]])
mask

img_new = np.zeros([m, n])

img_new

for i in range(1, m-2):
  for j in range(1, n-2):
    temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
    img_new[i, j]= temp
img_new = img_new.astype(np.uint8)
plt.imshow(img_new,cmap=plt.cm.gray)

# %%
mask=np.array([[1,2,1],[2,4,2],[1,2,1]])
mask = mask / 16

#Rmask=np.array([[1,0],[0,-1]])
mask

img_new = np.zeros([m, n])

img_new

for i in range(1, m-2):
  for j in range(1, n-2):
    temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
    img_new[i, j]= temp
img_new = img_new.astype(np.uint8)
plt.imshow(img_new,cmap=plt.cm.gray)

# %%
def display_images(images, titles, figsize=(15, 5)):

  plt.figure(figsize=figsize)
  for i in range(len(images)):
    plt.subplot(1, len(images), i+1), plt.imshow(images[i], cmap='gray')
    plt.title(titles[i])
    plt.xticks([]), plt.yticks([])

mask=np.array([[1,2,1],[2,4,2],[1,2,1]])
mask = mask / 16

#Rmask=np.array([[1,0],[0,-1]])
mask

img1 = np.zeros([m, n])


for i in range(1, m-2):
  for j in range(1, n-2):
    temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
    img1[i, j]= temp
img1 = img1.astype(np.uint8)

mask = np.ones([3, 3], dtype = int)
#mask=np.array([[-1,0,1],[-2,0,2],[-1,0,1]])
mask = mask / 9

#Rmask=np.array([[1,0],[0,-1]])
mask

img2 = np.zeros([m, n])


for i in range(1, m-2):
  for j in range(1, n-2):
    temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
    img2[i, j]= temp
img2 = img_new.astype(np.uint8)

output_images = [img1,img2]

display_images([img] + output_images,['img'] + ['img1', 'img2'])
plt.show()

# %%
[m,n] = img_new.shape;

m,n

#mask = np.ones([3, 3], dtype = int)
mask=np.array([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])


img_newC= np.zeros([m, n])

img_newC

for i in range(1, m-2):
  for j in range(1, n-2):
    temp = img_new[i-1, j-1]*mask[0, 0]+img_new[i-1, j]*mask[0, 1]+img_new[i-1, j + 1]*mask[0, 2]+img_new[i, j-1]*mask[1, 0]+ img_new[i, j]*mask[1, 1]+img_new[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
    img_newC[i, j]= temp

img_newC = img_newC.astype(np.uint8)

img_newC
Hb=img_newC*0.2+img*0.8
Hb
# Out:
# array([[ 74.4,  64.8,  68. , ..., 129.6, 107.2,  68. ],
#        [ 84. ,  98.8,  81.2, ..., 112.4,  84.8,  83.2],
#        [ 71.2,  98.2, 135.2, ..., 110.8,  72.8,  77.6],
#        ...,
#        [ 60.8,  97.2, 120. , ...,  96.4,  77.6,  84. ],
#        [ 71.2,  77.6,  78.4, ...,  61.6,  55.2,  64.8],
#        [ 94.4,  90.4,  77.6, ...,  81.6,  55.2,  55.2]])

# %%
[m,n] = img_new.shape;

m,n

#mask = np.ones([3, 3], dtype = int)
mask=np.array([[-1,-1,-1],[0,0,0],[1,1,1]])


img_newC= np.zeros([m, n])

img_newC

for i in range(1, m-2):
  for j in range(1, n-2):
    temp = img_new[i-1, j-1]*mask[0, 0]+img_new[i-1, j]*mask[0, 1]+img_new[i-1, j + 1]*mask[0, 2]+img_new[i, j-1]*mask[1, 0]+ img_new[i, j]*mask[1, 1]+img_new[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
    img_newC[i, j]= temp

img_newC = img_newC.astype(np.uint8)

img_newC
Hb1=img_newC*0.2+img*0.8
Hb1
# Out:
# array([[ 74.4,  64.8,  68. , ..., 129.6, 107.2,  68. ],
#        [ 84. ,  83.6,  81.6, ..., 106.8,  84.8,  83.2],
#        [ 71.2,  93. , 107.4, ...,  99. ,  72.8,  77.6],
#        ...,
#        [ 60.8,  92.4,  78. , ...,  72.4,  77.6,  84. ],
#        [ 71.2,  77.6,  78.4, ...,  61.6,  55.2,  64.8],
#        [ 94.4,  90.4,  77.6, ...,  81.6,  55.2,  55.2]])

# %%
[m,n] = img_new.shape;

m,n

#mask = np.ones([3, 3], dtype = int)
mask=np.array([[0,-1,0],[-1,4,-1],[0,-1,0]])


img_newC= np.zeros([m, n])

img_newC

for i in range(1, m-2):
  for j in range(1, n-2):
    temp = img_new[i-1, j-1]*mask[0, 0]+img_new[i-1, j]*mask[0, 1]+img_new[i-1, j + 1]*mask[0, 2]+img_new[i, j-1]*mask[1, 0]+ img_new[i, j]*mask[1, 1]+img_new[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
    img_newC[i, j]= temp

img_newC = img_newC.astype(np.uint8)

img_newC
Hb3=img_newC*0.2+img*0.8
Hb3
# Out:
# array([[ 74.4,  64.8,  68. , ..., 129.6, 107.2,  68. ],
#        [ 84. , 115.8,  90.8, ..., 103.2,  84.8,  83.2],
#        [ 71.2,  87.2, 140. , ...,  98. ,  72.8,  77.6],
#        ...,
#        [ 60.8,  82.8, 121. , ...,  77.2,  77.6,  84. ],
#        [ 71.2,  77.6,  78.4, ...,  61.6,  55.2,  64.8],
#        [ 94.4,  90.4,  77.6, ...,  81.6,  55.2,  55.2]])

# %%
[m,n] = img_new.shape;

m,n

#mask = np.ones([3, 3], dtype = int)
mask=np.array([[-1,0,1],[-2,0,2],[-1,0,1]])


img_newC= np.zeros([m, n])

img_newC

for i in range(1, m-2):
  for j in range(1, n-2):
    temp = img_new[i-1, j-1]*mask[0, 0]+img_new[i-1, j]*mask[0, 1]+img_new[i-1, j + 1]*mask[0, 2]+img_new[i, j-1]*mask[1, 0]+ img_new[i, j]*mask[1, 1]+img_new[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
    img_newC[i, j]= temp

img_newC = img_newC.astype(np.uint8)

img_newC
Hb4=img_newC*0.2+img*0.8
Hb4
# Out:
# array([[ 74.4,  64.8,  68. , ..., 129.6, 107.2,  68. ],
#        [ 84. , 120.6,  79.6, ..., 104.8,  84.8,  83.2],
#        [ 71.2,  82.6, 114.8, ..., 116. ,  72.8,  77.6],
#        ...,
#        [ 60.8,  70. ,  73. , ...,  66. ,  77.6,  84. ],
#        [ 71.2,  77.6,  78.4, ...,  61.6,  55.2,  64.8],
#        [ 94.4,  90.4,  77.6, ...,  81.6,  55.2,  55.2]])

# %%
mask=np.array([[1,2,1],[2,4,2],[1,2,1]])
mask = mask / 16

#Rmask=np.array([[1,0],[0,-1]])
mask

img_new = np.zeros([m, n])

img_new
for l in range(1,5):

  for i in range(1, m-2):
    for j in range(1, n-2):
      temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2]
      img_new[i, j]= temp
  img_new = img_new.astype(np.uint8)
  plt.imshow(img_new,cmap=plt.cm.gray)
